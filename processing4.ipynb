# %%
import os
os.chdir('C:/Users/drsur/Desktop/project')

# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %%
#Extracting features of 2020 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# C:\Users\drsur\AppData\Local\Temp\ipykernel_59508\1752420719.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                  Title  \
# 0     JANUARY          3             The Grudge
# 1     JANUARY         10             Underwater
# 2     JANUARY         10            Like a Boss
# 3     JANUARY         10          Three Christs
# 4     JANUARY         10      Inherit the Viper
# ..        ...        ...                    ...
# 270  DECEMBER         25       We Can Be Heroes
# 271  DECEMBER         25      News of the World
# 272  DECEMBER         25  One Night in Miami...
# 273  DECEMBER         25  Promising Young Woman
# 274  DECEMBER         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                                   Paramount Pictures
# 3                                            IFC Films
# 4       Barry Films / Tycor International Film Company
# ..                                                 ...
# 270                     Netflix / Troublemaker Studios
# 271        Universal Pictures / Perfect World Pictures
# 272                                     Amazon Studios
# 273          Focus Features / FilmNation Entertainment
# 274                             Netflix / Bron Studios
#
#                                          Cast and crew  \
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...
# 1    William Eubank (director); Brian Duffield, Ada...
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...
# 3    Jon Avnet (director/screenplay); Eric Nazarian...
# 4    Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                                                 ...
# 270  Robert Rodriguez (director/screenplay); Priyan...
# 271  Paul Greengrass (director/screenplay); Luke Da...
# 272  Regina King (director); Kemp Powers (screenpla...
# 273  Emerald Fennell (director/screenplay); Carey M...
# 274  Kornél Mundruczó (director); Kata Wéber (scree...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  NaN
# 4                                                  [5]
# ..                                                 ...
# 270                                                NaN
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 270  [241]
# 271  [242]
# 272  [243]
# 273  [244]
# 274  [245]
#
# [275 rows x 7 columns]

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
df_2020
# Out:
#                      Title                                      Cast and crew
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 270       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 271      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 272  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 273  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 274      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# [275 rows x 2 columns]

# %%
# !pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in c:\users\drsur\miniconda3\lib\site-packages (1.7.6)
# Requirement already satisfied: requests in c:\users\drsur\miniconda3\lib\site-packages (from tmdbv3api) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\drsur\miniconda3\lib\site-packages (from requests->tmdbv3api) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\drsur\miniconda3\lib\site-packages (from requests->tmdbv3api) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\drsur\miniconda3\lib\site-packages (from requests->tmdbv3api) (2022.5.18.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\drsur\miniconda3\lib\site-packages (from requests->tmdbv3api) (3.3)

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'fbcfda2c9d8e983ce0fc23cd9bdad189'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))
# Out:
# C:\Users\drsur\AppData\Local\Temp\ipykernel_59508\2588226551.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 270       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 271      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 272  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 273  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 274      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                      genres
# 0                   Horror Mystery Thriller
# 1    Action Horror Science Fiction Thriller
# 2                                    Comedy
# 3                                     Drama
# 4                      Crime Thriller Drama
# ..                                      ...
# 270            Action Fantasy Family Comedy
# 271                 Drama Western Adventure
# 272                                   Drama
# 273                    Thriller Crime Drama
# 274                                   Drama
#
# [275 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\drsur\AppData\Local\Temp\ipykernel_59508\3848435694.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\Users\drsur\AppData\Local\Temp\ipykernel_59508\3646981363.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# C:\Users\drsur\AppData\Local\Temp\ipykernel_59508\463054939.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 270       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 271      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 272  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 273  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 274      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                      genres     director_name  \
# 0                   Horror Mystery Thriller     Nicolas Pesce
# 1    Action Horror Science Fiction Thriller    William Eubank
# 2                                    Comedy     Miguel Arteta
# 3                                     Drama         Jon Avnet
# 4                      Crime Thriller Drama    Anthony Jerjen
# ..                                      ...               ...
# 270            Action Fantasy Family Comedy  Robert Rodriguez
# 271                 Drama Western Adventure   Paul Greengrass
# 272                                   Drama       Regina King
# 273                    Thriller Crime Drama   Emerald Fennell
# 274                                   Drama  Kornél Mundruczó
#
#               actor_1_name       actor_2_name     actor_3_name
# 0       Andrea Riseborough      Demián Bichir         John Cho
# 1          Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2          Tiffany Haddish         Rose Byrne      Salma Hayek
# 3             Richard Gere     Peter Dinklage   Walton Goggins
# 4            Josh Hartnett  Margarita Levieva   Chandler Riggs
# ..                     ...                ...              ...
# 270  Priyanka Chopra Jonas       Pedro Pascal    YaYa Gosselin
# 271              Tom Hanks      Helena Zengel              NaN
# 272      Kingsley Ben-Adir          Eli Goree      Aldis Hodge
# 273         Carey Mulligan         Bo Burnham      Alison Brie
# 274          Vanessa Kirby       Shia LaBeouf     Molly Parker
#
# [275 rows x 7 columns]

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 270  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 271   Paul Greengrass              Tom Hanks      Helena Zengel
# 272       Regina King      Kingsley Ben-Adir          Eli Goree
# 273   Emerald Fennell         Carey Mulligan         Bo Burnham
# 274  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                  genres  \
# 0           John Cho                 Horror Mystery Thriller
# 1    Jessica Henwick  Action Horror Science Fiction Thriller
# 2        Salma Hayek                                  Comedy
# 3     Walton Goggins                                   Drama
# 4     Chandler Riggs                    Crime Thriller Drama
# ..               ...                                     ...
# 270    YaYa Gosselin            Action Fantasy Family Comedy
# 271              NaN                 Drama Western Adventure
# 272      Aldis Hodge                                   Drama
# 273      Alison Brie                    Thriller Crime Drama
# 274     Molly Parker                                   Drama
#
#                movie_title
# 0               The Grudge
# 1               Underwater
# 2              Like a Boss
# 3            Three Christs
# 4        Inherit the Viper
# ..                     ...
# 270       We Can Be Heroes
# 271      News of the World
# 272  One Night in Miami...
# 273  Promising Young Woman
# 274      Pieces of a Woman
#
# [275 rows x 6 columns]

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']

# %%
#Extracting features of 2021 movies from Wikipedia

# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]

# %%
df
# Out:
#       Opening  Opening.1                  Title  \
# 0     JANUARY          3             The Grudge
# 1     JANUARY         10             Underwater
# 2     JANUARY         10            Like a Boss
# 3     JANUARY         10          Three Christs
# 4     JANUARY         10      Inherit the Viper
# ..        ...        ...                    ...
# 270  DECEMBER         25       We Can Be Heroes
# 271  DECEMBER         25      News of the World
# 272  DECEMBER         25  One Night in Miami...
# 273  DECEMBER         25  Promising Young Woman
# 274  DECEMBER         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                                   Paramount Pictures
# 3                                            IFC Films
# 4       Barry Films / Tycor International Film Company
# ..                                                 ...
# 270                     Netflix / Troublemaker Studios
# 271        Universal Pictures / Perfect World Pictures
# 272                                     Amazon Studios
# 273          Focus Features / FilmNation Entertainment
# 274                             Netflix / Bron Studios
#
#                                          Cast and crew  \
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...
# 1    William Eubank (director); Brian Duffield, Ada...
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...
# 3    Jon Avnet (director/screenplay); Eric Nazarian...
# 4    Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                                                 ...
# 270  Robert Rodriguez (director/screenplay); Priyan...
# 271  Paul Greengrass (director/screenplay); Luke Da...
# 272  Regina King (director); Kemp Powers (screenpla...
# 273  Emerald Fennell (director/screenplay); Carey M...
# 274  Kornél Mundruczó (director); Kata Wéber (scree...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  NaN
# 4                                                  [5]
# ..                                                 ...
# 270                                                NaN
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 270  [241]
# 271  [242]
# 272  [243]
# 273  [244]
# 274  [245]
#
# [275 rows x 7 columns]

# %%
df_2021 = df[['Title','Cast and crew']]

# %%
df_2021
# Out:
#                      Title                                      Cast and crew
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 270       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 271      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 272  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 273  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 274      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# [275 rows x 2 columns]

# %%
# !pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in c:\users\drsur\miniconda3\lib\site-packages (1.7.6)
# Requirement already satisfied: requests in c:\users\drsur\miniconda3\lib\site-packages (from tmdbv3api) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\drsur\miniconda3\lib\site-packages (from requests->tmdbv3api) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\drsur\miniconda3\lib\site-packages (from requests->tmdbv3api) (2022.5.18.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\drsur\miniconda3\lib\site-packages (from requests->tmdbv3api) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\drsur\miniconda3\lib\site-packages (from requests->tmdbv3api) (2.0.4)

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'fbcfda2c9d8e983ce0fc23cd9bdad189'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2021['genres'] = df_2021['Title'].map(lambda x: get_genre(str(x)))
# Out:
# C:\Users\drsur\AppData\Local\Temp\ipykernel_59508\3587185986.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['genres'] = df_2021['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2021
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 270       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 271      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 272  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 273  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 274      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                      genres
# 0                   Horror Mystery Thriller
# 1    Action Horror Science Fiction Thriller
# 2                                    Comedy
# 3                                     Drama
# 4                      Crime Thriller Drama
# ..                                      ...
# 270            Action Fantasy Family Comedy
# 271                 Drama Western Adventure
# 272                                   Drama
# 273                    Thriller Crime Drama
# 274                                   Drama
#
# [275 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\drsur\AppData\Local\Temp\ipykernel_59508\3118254134.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\Users\drsur\AppData\Local\Temp\ipykernel_59508\1611661901.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# C:\Users\drsur\AppData\Local\Temp\ipykernel_59508\3001516348.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2021
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 270       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 271      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 272  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 273  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 274      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                      genres     director_name  \
# 0                   Horror Mystery Thriller     Nicolas Pesce
# 1    Action Horror Science Fiction Thriller    William Eubank
# 2                                    Comedy     Miguel Arteta
# 3                                     Drama         Jon Avnet
# 4                      Crime Thriller Drama    Anthony Jerjen
# ..                                      ...               ...
# 270            Action Fantasy Family Comedy  Robert Rodriguez
# 271                 Drama Western Adventure   Paul Greengrass
# 272                                   Drama       Regina King
# 273                    Thriller Crime Drama   Emerald Fennell
# 274                                   Drama  Kornél Mundruczó
#
#               actor_1_name       actor_2_name     actor_3_name
# 0       Andrea Riseborough      Demián Bichir         John Cho
# 1          Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2          Tiffany Haddish         Rose Byrne      Salma Hayek
# 3             Richard Gere     Peter Dinklage   Walton Goggins
# 4            Josh Hartnett  Margarita Levieva   Chandler Riggs
# ..                     ...                ...              ...
# 270  Priyanka Chopra Jonas       Pedro Pascal    YaYa Gosselin
# 271              Tom Hanks      Helena Zengel              NaN
# 272      Kingsley Ben-Adir          Eli Goree      Aldis Hodge
# 273         Carey Mulligan         Bo Burnham      Alison Brie
# 274          Vanessa Kirby       Shia LaBeouf     Molly Parker
#
# [275 rows x 7 columns]

# %%
df_2021 = df_2021.rename(columns={'Title':'movie_title'})

# %%
new_df21 = df_2021.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
my_df = new_df20.append(new_df21,ignore_index=True)
# Out:
# C:\Users\drsur\AppData\Local\Temp\ipykernel_59508\2792808767.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   my_df = new_df20.append(new_df21,ignore_index=True)

# %%
my_df.isna().sum()
# Out:
# director_name      0
# actor_1_name       0
# actor_2_name      10
# actor_3_name      56
# genres             4
# movie_title        0
# comb             304
# dtype: int64

# %%
my_df = new_df20.dropna(how='any')

# %%
my_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
my_df['movie_title'] = my_df['movie_title'].str.lower()
# Out:
# C:\Users\drsur\AppData\Local\Temp\ipykernel_59508\317990521.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   my_df['movie_title'] = my_df['movie_title'].str.lower()

# %%
my_df
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 269       Pete Docter             Jamie Foxx           Tina Fey
# 270  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 272       Regina King      Kingsley Ben-Adir          Eli Goree
# 273   Emerald Fennell         Carey Mulligan         Bo Burnham
# 274  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                  genres  \
# 0           John Cho                 Horror Mystery Thriller
# 1    Jessica Henwick  Action Horror Science Fiction Thriller
# 2        Salma Hayek                                  Comedy
# 3     Walton Goggins                                   Drama
# 4     Chandler Riggs                    Crime Thriller Drama
# ..               ...                                     ...
# 269    Graham Norton         Animation Comedy Fantasy Family
# 270    YaYa Gosselin            Action Fantasy Family Comedy
# 272      Aldis Hodge                                   Drama
# 273      Alison Brie                    Thriller Crime Drama
# 274     Molly Parker                                   Drama
#
#                movie_title                                               comb
# 0               the grudge  Andrea Riseborough Demián Bichir John Cho Nico...
# 1               underwater  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2              like a boss  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3            three christs  Richard Gere Peter Dinklage Walton Goggins Jon...
# 4        inherit the viper  Josh Hartnett Margarita Levieva Chandler Riggs...
# ..                     ...                                                ...
# 269                   soul  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 270       we can be heroes  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 272  one night in miami...  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 273  promising young woman  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 274      pieces of a woman  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [246 rows x 7 columns]

# %%
old_df = pd.read_csv('new_data.csv')

# %%
old_df
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0             James Cameron           CCH Pounder        Joel David Moore
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5359            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5360            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5361       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5362  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5363           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 5359       Keith Stanfield                   Romance Comedy
# 5360     Jean Louisa Kelly                          Romance
# 5361        Tiitus Rantala                   Romance Comedy
# 5362           Gina Holden       Crime Comedy Action Family
# 5363        Akshaye Khanna             Crime Drama Thriller
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5359                       the incredible jessica james
# 5360                                  can't buy my love
# 5361                   thick lashes of lauri mäntyvaara
# 5362                        cop and a half: new recruit
# 5363                                                mom
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5359  Jessica Williams Chris O'Dowd Keith Stanfield ...
# 5360  Adelaide Kane Benjamin Hollingsworth Jean Loui...
# 5361  Inka Haapamäki Rosa Honkonen Tiitus Rantala Ha...
# 5362  Lou Diamond Phillips Wallace Shawn Gina Holden...
# 5363  Sridevi Kapoor Sajal Ali Akshaye Khanna Ravi U...
#
# [5364 rows x 7 columns]

# %%
final_df = old_df.append(my_df,ignore_index=True)
# Out:
# C:\Users\drsur\AppData\Local\Temp\ipykernel_59508\2046453413.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = old_df.append(my_df,ignore_index=True)

# %%
final_df
# Out:
#           director_name           actor_1_name      actor_2_name  \
# 0         James Cameron            CCH Pounder  Joel David Moore
# 1        Gore Verbinski            Johnny Depp     Orlando Bloom
# 2            Sam Mendes        Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan              Tom Hardy    Christian Bale
# 4           Doug Walker            Doug Walker        Rob Walker
# ...                 ...                    ...               ...
# 5605        Pete Docter             Jamie Foxx          Tina Fey
# 5606   Robert Rodriguez  Priyanka Chopra Jonas      Pedro Pascal
# 5607        Regina King      Kingsley Ben-Adir         Eli Goree
# 5608    Emerald Fennell         Carey Mulligan        Bo Burnham
# 5609   Kornél Mundruczó          Vanessa Kirby      Shia LaBeouf
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 5605         Graham Norton  Animation Comedy Fantasy Family
# 5606         YaYa Gosselin     Action Fantasy Family Comedy
# 5607           Aldis Hodge                            Drama
# 5608           Alison Brie             Thriller Crime Drama
# 5609          Molly Parker                            Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5605                                               soul
# 5606                                   we can be heroes
# 5607                              one night in miami...
# 5608                              promising young woman
# 5609                                  pieces of a woman
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5605  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 5606  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 5607  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 5608  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 5609  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [5610 rows x 7 columns]

# %%
final_df.isna().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of       director_name  actor_1_name  actor_2_name  actor_3_name  genres  \
# 0             False         False         False         False   False
# 1             False         False         False         False   False
# 2             False         False         False         False   False
# 3             False         False         False         False   False
# 4             False         False         False         False   False
# ...             ...           ...           ...           ...     ...
# 5605          False         False         False         False   False
# 5606          False         False         False         False   False
# 5607          False         False         False         False   False
# 5608          False         False         False         False   False
# 5609          False         False         False         False   False
#
#       movie_title   comb
# 0           False  False
# 1           False  False
# 2           False  False
# 3           False  False
# 4           False  False
# ...           ...    ...
# 5605        False  False
# 5606        False  False
# 5607        False  False
# 5608        False  False
# 5609        False  False
#
# [5610 rows x 7 columns]>

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.to_csv('main_data.csv',index=False)

# %%
#Extracting features of 2022 movies from Wikipedia

# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2022"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]

# %%
df = df1.append(df2,ignore_index=True)
# Out:
# C:\Users\drsur\AppData\Local\Temp\ipykernel_59508\4176271390.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2,ignore_index=True)

# %%
df
# Out:
#      Opening  Opening.1                              Title  \
# 0    JANUARY          7                            The 355
# 1    JANUARY          7           The Legend of La Llorona
# 2    JANUARY          7                       The Commando
# 3    JANUARY         14                             Scream
# 4    JANUARY         14  Hotel Transylvania: Transformania
# ..       ...        ...                                ...
# 123     JUNE         24                    The Black Phone
# 124     JUNE         24               The Man from Toronto
# 125     JUNE         24     Marcel the Shell with Shoes On
# 126     JUNE         24                               Rise
# 127     JUNE         24                         Press Play
#
#                                     Production company  \
# 0    Universal Pictures / Freckle Films / FilmNatio...
# 1                                          Saban Films
# 2                                          Saban Films
# 3            Paramount Pictures / Spyglass Media Group
# 4    Amazon Studios / Columbia Pictures / Sony Pict...
# ..                                                 ...
# 123         Universal Pictures / Blumhouse Productions
# 124  Netflix / Sony Pictures / Bron Creative / Esca...
# 125                                    A24 / Cinereach
# 126                     Disney+ / Walt Disney Pictures
# 127                      The Avenue / CJ Entertainment
#
#                                          Cast and crew  \
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Matt Bettinelli-Olpin, Tyler Gillett (director...
# 4    Jennifer Kluska, Derek Drymon (directors); Amo...
# ..                                                 ...
# 123  Scott Derrickson (director/screenplay); C. Rob...
# 124  Patrick Hughes (director); Robbie Fox, Chris B...
# 125  Dean Fleischer-Camp (director/screenplay); Jen...
# 126  Akin Omotoso (director); Arash Amel (screenpla...
# 127  Greg Björkman (director/screenplay); James Bac...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  [5]
# 4                                                  [6]
# ..                                                 ...
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 123  [112]
# 124  [113]
# 125  [114]
# 126  [115]
# 127  [116]
#
# [128 rows x 7 columns]

# %%
df_2022 = df[['Title','Cast and crew']]

# %%
df_2022
# Out:
#                                  Title  \
# 0                              The 355
# 1             The Legend of La Llorona
# 2                         The Commando
# 3                               Scream
# 4    Hotel Transylvania: Transformania
# ..                                 ...
# 123                    The Black Phone
# 124               The Man from Toronto
# 125     Marcel the Shell with Shoes On
# 126                               Rise
# 127                         Press Play
#
#                                          Cast and crew
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Matt Bettinelli-Olpin, Tyler Gillett (director...
# 4    Jennifer Kluska, Derek Drymon (directors); Amo...
# ..                                                 ...
# 123  Scott Derrickson (director/screenplay); C. Rob...
# 124  Patrick Hughes (director); Robbie Fox, Chris B...
# 125  Dean Fleischer-Camp (director/screenplay); Jen...
# 126  Akin Omotoso (director); Arash Amel (screenpla...
# 127  Greg Björkman (director/screenplay); James Bac...
#
# [128 rows x 2 columns]

# %%
# !pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in c:\users\drsur\miniconda3\lib\site-packages (1.7.6)
# Requirement already satisfied: requests in c:\users\drsur\miniconda3\lib\site-packages (from tmdbv3api) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\drsur\miniconda3\lib\site-packages (from requests->tmdbv3api) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\drsur\miniconda3\lib\site-packages (from requests->tmdbv3api) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\drsur\miniconda3\lib\site-packages (from requests->tmdbv3api) (2022.5.18.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\drsur\miniconda3\lib\site-packages (from requests->tmdbv3api) (2.0.4)

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'fbcfda2c9d8e983ce0fc23cd9bdad189'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2022['genres'] = df_2022['Title'].map(lambda x: get_genre(str(x)))
# Out:
# C:\Users\drsur\AppData\Local\Temp\ipykernel_59508\2369738557.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['genres'] = df_2022['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2022
# Out:
#                                  Title  \
# 0                              The 355
# 1             The Legend of La Llorona
# 2                         The Commando
# 3                               Scream
# 4    Hotel Transylvania: Transformania
# ..                                 ...
# 123                    The Black Phone
# 124               The Man from Toronto
# 125     Marcel the Shell with Shoes On
# 126                               Rise
# 127                         Press Play
#
#                                          Cast and crew  \
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Matt Bettinelli-Olpin, Tyler Gillett (director...
# 4    Jennifer Kluska, Derek Drymon (directors); Amo...
# ..                                                 ...
# 123  Scott Derrickson (director/screenplay); C. Rob...
# 124  Patrick Hughes (director); Robbie Fox, Chris B...
# 125  Dean Fleischer-Camp (director/screenplay); Jen...
# 126  Akin Omotoso (director); Arash Amel (screenpla...
# 127  Greg Björkman (director/screenplay); James Bac...
#
#                                         genres
# 0                              Action Thriller
# 1                              Horror Thriller
# 2                        Action Crime Thriller
# 3                      Horror Mystery Thriller
# 4    Animation Family Fantasy Comedy Adventure
# ..                                         ...
# 123                            Horror Thriller
# 124                              Action Comedy
# 125          Animation Adventure Comedy Family
# 126   Family Animation Action Adventure Comedy
# 127              Romance Drama Science Fiction
#
# [128 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\drsur\AppData\Local\Temp\ipykernel_59508\3796821595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\Users\drsur\AppData\Local\Temp\ipykernel_59508\2929607607.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# C:\Users\drsur\AppData\Local\Temp\ipykernel_59508\2384233428.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2022['actor_3_name'] = df_2022['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2022
# Out:
#                                  Title  \
# 0                              The 355
# 1             The Legend of La Llorona
# 2                         The Commando
# 3                               Scream
# 4    Hotel Transylvania: Transformania
# ..                                 ...
# 123                    The Black Phone
# 124               The Man from Toronto
# 125     Marcel the Shell with Shoes On
# 126                               Rise
# 127                         Press Play
#
#                                          Cast and crew  \
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Matt Bettinelli-Olpin, Tyler Gillett (director...
# 4    Jennifer Kluska, Derek Drymon (directors); Amo...
# ..                                                 ...
# 123  Scott Derrickson (director/screenplay); C. Rob...
# 124  Patrick Hughes (director); Robbie Fox, Chris B...
# 125  Dean Fleischer-Camp (director/screenplay); Jen...
# 126  Akin Omotoso (director); Arash Amel (screenpla...
# 127  Greg Björkman (director/screenplay); James Bac...
#
#                                         genres  \
# 0                              Action Thriller
# 1                              Horror Thriller
# 2                        Action Crime Thriller
# 3                      Horror Mystery Thriller
# 4    Animation Family Fantasy Comedy Adventure
# ..                                         ...
# 123                            Horror Thriller
# 124                              Action Comedy
# 125          Animation Adventure Comedy Family
# 126   Family Animation Action Adventure Comedy
# 127              Romance Drama Science Fiction
#
#                             director_name      actor_1_name  \
# 0                           Simon Kinberg  Jessica Chastain
# 1                  Patricia Harris Seeley     Autumn Reeser
# 2                              Asif Akbar     Mickey Rourke
# 3    Matt Bettinelli-Olpin, Tyler Gillett   Melissa Barrera
# 4           Jennifer Kluska, Derek Drymon      Andy Samberg
# ..                                    ...               ...
# 123                      Scott Derrickson       Ethan Hawke
# 124                        Patrick Hughes        Kevin Hart
# 125                   Dean Fleischer-Camp       Jenny Slate
# 126                          Akin Omotoso        Uche Agada
# 127                         Greg Björkman     Clara Rugaard
#
#           actor_2_name      actor_3_name
# 0       Lupita Nyong'o     Penélope Cruz
# 1         Antonio Cupo       Danny Trejo
# 2    Michael Jai White               NaN
# 3        Mason Gooding      Jenna Ortega
# 4         Selena Gomez      Kathryn Hahn
# ..                 ...               ...
# 123       Mason Thames  Madeleine McGraw
# 124    Woody Harrelson       Kaley Cuoco
# 125       Rosa Salazar       Thomas Mann
# 126          Ral Agada     Jaden Osimuwa
# 127      Lewis Pullman      Lyrica Okano
#
# [128 rows x 7 columns]

# %%
df_2022 = df_2022.rename(columns={'Title':'movie_title'})

# %%
new_df22 = df_2022.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df22
# Out:
#                             director_name      actor_1_name  \
# 0                           Simon Kinberg  Jessica Chastain
# 1                  Patricia Harris Seeley     Autumn Reeser
# 2                              Asif Akbar     Mickey Rourke
# 3    Matt Bettinelli-Olpin, Tyler Gillett   Melissa Barrera
# 4           Jennifer Kluska, Derek Drymon      Andy Samberg
# ..                                    ...               ...
# 123                      Scott Derrickson       Ethan Hawke
# 124                        Patrick Hughes        Kevin Hart
# 125                   Dean Fleischer-Camp       Jenny Slate
# 126                          Akin Omotoso        Uche Agada
# 127                         Greg Björkman     Clara Rugaard
#
#           actor_2_name      actor_3_name  \
# 0       Lupita Nyong'o     Penélope Cruz
# 1         Antonio Cupo       Danny Trejo
# 2    Michael Jai White               NaN
# 3        Mason Gooding      Jenna Ortega
# 4         Selena Gomez      Kathryn Hahn
# ..                 ...               ...
# 123       Mason Thames  Madeleine McGraw
# 124    Woody Harrelson       Kaley Cuoco
# 125       Rosa Salazar       Thomas Mann
# 126          Ral Agada     Jaden Osimuwa
# 127      Lewis Pullman      Lyrica Okano
#
#                                         genres  \
# 0                              Action Thriller
# 1                              Horror Thriller
# 2                        Action Crime Thriller
# 3                      Horror Mystery Thriller
# 4    Animation Family Fantasy Comedy Adventure
# ..                                         ...
# 123                            Horror Thriller
# 124                              Action Comedy
# 125          Animation Adventure Comedy Family
# 126   Family Animation Action Adventure Comedy
# 127              Romance Drama Science Fiction
#
#                            movie_title
# 0                              The 355
# 1             The Legend of La Llorona
# 2                         The Commando
# 3                               Scream
# 4    Hotel Transylvania: Transformania
# ..                                 ...
# 123                    The Black Phone
# 124               The Man from Toronto
# 125     Marcel the Shell with Shoes On
# 126                               Rise
# 127                         Press Play
#
# [128 rows x 6 columns]

# %%
new_df22['comb'] = new_df22['actor_1_name'] + ' ' + new_df22['actor_2_name'] + ' '+ new_df22['actor_3_name'] + ' '+ new_df22['director_name'] +' ' + new_df22['genres']

# %%
my_df = new_df21.append(new_df20,ignore_index=True)
# Out:
# C:\Users\drsur\AppData\Local\Temp\ipykernel_59508\4145860607.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   my_df = new_df21.append(new_df20,ignore_index=True)

# %%
my_df.isna().sum()
# Out:
# director_name      0
# actor_1_name       0
# actor_2_name      10
# actor_3_name      56
# genres             4
# movie_title        0
# comb             304
# dtype: int64

# %%
my_df = new_df22.dropna(how='any')

# %%
my_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
my_df['movie_title'] = my_df['movie_title'].str.lower()
# Out:
# C:\Users\drsur\AppData\Local\Temp\ipykernel_59508\317990521.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   my_df['movie_title'] = my_df['movie_title'].str.lower()

# %%
my_df
# Out:
#                             director_name      actor_1_name     actor_2_name  \
# 0                           Simon Kinberg  Jessica Chastain   Lupita Nyong'o
# 1                  Patricia Harris Seeley     Autumn Reeser     Antonio Cupo
# 3    Matt Bettinelli-Olpin, Tyler Gillett   Melissa Barrera    Mason Gooding
# 4           Jennifer Kluska, Derek Drymon      Andy Samberg     Selena Gomez
# 5                             Luis Prieto  Cameron Monaghan     Frank Grillo
# ..                                    ...               ...              ...
# 123                      Scott Derrickson       Ethan Hawke     Mason Thames
# 124                        Patrick Hughes        Kevin Hart  Woody Harrelson
# 125                   Dean Fleischer-Camp       Jenny Slate     Rosa Salazar
# 126                          Akin Omotoso        Uche Agada        Ral Agada
# 127                         Greg Björkman     Clara Rugaard    Lewis Pullman
#
#          actor_3_name                                     genres  \
# 0       Penélope Cruz                            Action Thriller
# 1         Danny Trejo                            Horror Thriller
# 3        Jenna Ortega                    Horror Mystery Thriller
# 4        Kathryn Hahn  Animation Family Fantasy Comedy Adventure
# 5          Lilly Krug                                   Thriller
# ..                ...                                        ...
# 123  Madeleine McGraw                            Horror Thriller
# 124       Kaley Cuoco                              Action Comedy
# 125       Thomas Mann          Animation Adventure Comedy Family
# 126     Jaden Osimuwa   Family Animation Action Adventure Comedy
# 127      Lyrica Okano              Romance Drama Science Fiction
#
#                            movie_title  \
# 0                              the 355
# 1             the legend of la llorona
# 3                               scream
# 4    hotel transylvania: transformania
# 5                            shattered
# ..                                 ...
# 123                    the black phone
# 124               the man from toronto
# 125     marcel the shell with shoes on
# 126                               rise
# 127                         press play
#
#                                                   comb
# 0    Jessica Chastain Lupita Nyong'o Penélope Cruz ...
# 1    Autumn Reeser Antonio Cupo Danny Trejo Patrici...
# 3    Melissa Barrera Mason Gooding Jenna Ortega Mat...
# 4    Andy Samberg Selena Gomez Kathryn Hahn Jennife...
# 5    Cameron Monaghan Frank Grillo Lilly Krug Luis ...
# ..                                                 ...
# 123  Ethan Hawke Mason Thames Madeleine McGraw Scot...
# 124  Kevin Hart Woody Harrelson Kaley Cuoco Patrick...
# 125  Jenny Slate Rosa Salazar Thomas Mann Dean Flei...
# 126  Uche Agada Ral Agada Jaden Osimuwa Akin Omotos...
# 127  Clara Rugaard Lewis Pullman Lyrica Okano Greg ...
#
# [118 rows x 7 columns]

# %%
old_df = pd.read_csv('final_data.csv')

# %%
old_df
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              James Cameron        CCH Pounder      Joel David Moore
# 1             Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                 Sam Mendes    Christoph Waltz          Rory Kinnear
# 3          Christopher Nolan          Tom Hardy        Christian Bale
# 4                Doug Walker        Doug Walker            Rob Walker
# ...                      ...                ...                   ...
# 5871  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 5872            Greta Gerwig      Saoirse Ronan           Emma Watson
# 5873              Sam Mendes      George MacKay  Dean-Charles Chapman
# 5874   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5875         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                    genres  \
# 0                Wes Studi           Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport                  Action Adventure Fantasy
# 2         Stephanie Sigman                 Action Adventure Thriller
# 3     Joseph Gordon-Levitt                           Action Thriller
# 4                  unknown                               Documentary
# ...                    ...                                       ...
# 5871         Rashida Jones  Animation Action Adventure Comedy Family
# 5872         Florence Pugh                             Drama Romance
# 5873           Mark Strong                 War Drama Action Thriller
# 5874           Brie Larson                       Drama Crime History
# 5875           Aldis Hodge                                     Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5871                                  spies in disguise
# 5872                                       little women
# 5873                                               1917
# 5874                                         just mercy
# 5875                                           clemency
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5871  Will Smith Tom Holland Rashida Jones Nick Brun...
# 5872  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5873  George MacKay Dean-Charles Chapman Mark Strong...
# 5874  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5875  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [5876 rows x 7 columns]

# %%
final_df = old_df.append(my_df,ignore_index=True)
# Out:
# C:\Users\drsur\AppData\Local\Temp\ipykernel_59508\2046453413.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = old_df.append(my_df,ignore_index=True)

# %%
final_df
# Out:
#             director_name     actor_1_name      actor_2_name  \
# 0           James Cameron      CCH Pounder  Joel David Moore
# 1          Gore Verbinski      Johnny Depp     Orlando Bloom
# 2              Sam Mendes  Christoph Waltz      Rory Kinnear
# 3       Christopher Nolan        Tom Hardy    Christian Bale
# 4             Doug Walker      Doug Walker        Rob Walker
# ...                   ...              ...               ...
# 5989     Scott Derrickson      Ethan Hawke      Mason Thames
# 5990       Patrick Hughes       Kevin Hart   Woody Harrelson
# 5991  Dean Fleischer-Camp      Jenny Slate      Rosa Salazar
# 5992         Akin Omotoso       Uche Agada         Ral Agada
# 5993        Greg Björkman    Clara Rugaard     Lewis Pullman
#
#               actor_3_name                                    genres  \
# 0                Wes Studi           Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport                  Action Adventure Fantasy
# 2         Stephanie Sigman                 Action Adventure Thriller
# 3     Joseph Gordon-Levitt                           Action Thriller
# 4                  unknown                               Documentary
# ...                    ...                                       ...
# 5989      Madeleine McGraw                           Horror Thriller
# 5990           Kaley Cuoco                             Action Comedy
# 5991           Thomas Mann         Animation Adventure Comedy Family
# 5992         Jaden Osimuwa  Family Animation Action Adventure Comedy
# 5993          Lyrica Okano             Romance Drama Science Fiction
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5989                                    the black phone
# 5990                               the man from toronto
# 5991                     marcel the shell with shoes on
# 5992                                               rise
# 5993                                         press play
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5989  Ethan Hawke Mason Thames Madeleine McGraw Scot...
# 5990  Kevin Hart Woody Harrelson Kaley Cuoco Patrick...
# 5991  Jenny Slate Rosa Salazar Thomas Mann Dean Flei...
# 5992  Uche Agada Ral Agada Jaden Osimuwa Akin Omotos...
# 5993  Clara Rugaard Lewis Pullman Lyrica Okano Greg ...
#
# [5994 rows x 7 columns]

# %%
final_df.to_csv('main_data.csv',index=False)
